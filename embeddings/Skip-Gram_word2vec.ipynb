# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:28, 1.10MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs={word: count/total_count for word, count in word_counts.items()}
p_drop ={word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}

# The final subsampled word list
train_words = [word for word in int_words if random.random()<(1-p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R= np.random.randint(1,window_size+1)
    if idx-R>0:
        start = idx-R 
    else:
        start = 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
      
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name='inputs')
    labels = tf.placeholder(tf.int32,[None,None],name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)

 # Number of embedding features 
n_embedding = 200

with train_graph.as_default():
    
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding),-1,1))
    
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding,inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding),stddev=0.1))

    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w,softmax_b,labels,embed,n_sampled,n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /Users/Jose/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1310: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-14-0edb403d10d5>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6886 0.3056 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6262 0.3112 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5192 0.3092 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5941 0.3310 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5075 0.3025 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5547 0.2985 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5774 0.3041 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5430 0.3015 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5072 0.3153 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4664 0.3047 sec/batch
# Nearest to no: tense, stick, seats, mica, khoikhoi, debbie, knicks, shelled,
# Nearest to they: flatland, couturat, dare, hitpa, engraved, fossil, kullervo, harnad,
# Nearest to eight: notaries, aves, creoles, hacker, decide, ebb, motets, cellphone,
# Nearest to five: slays, posters, master, prover, dizzy, cigar, eds, painful,
# Nearest to time: thirsty, derrick, gym, imbibed, hemp, allowable, enrico, vroma,
# Nearest to where: arcades, abaddon, sepia, veteris, strolling, amn, verde, varies,
# Nearest to three: chronos, hurts, woollen, agreement, administrative, poked, tiananmen, rhone,
# Nearest to world: norouz, taraza, harnack, onassis, typewriters, ayurveda, lica, vayikra,
# Nearest to alternative: mcmahon, involvements, maleficarum, pirandello, angst, analogical, rupiah, sparring,
# Nearest to animals: aqsa, ac, landing, fundraising, amoeboid, boomer, prepared, uplink,
# Nearest to grand: abbey, dench, pendant, knotted, xp, unbroken, gelderland, surname,
# Nearest to channel: melancholic, your, relapsed, gto, dollar, afoul, investigation, cyclical,
# Nearest to something: unsafe, ryan, mclain, heavily, pokemon, sinusoidal, sputnik, rightness,
# Nearest to institute: kami, geopolitical, voortrekkers, squalor, vigilantes, calories, vicki, oneness,
# Nearest to quite: orators, tauris, dogsled, challenged, andover, introduces, foamy, iole,
# Nearest to paris: belichick, tensor, murdock, buster, imp, numerous, sepulchre, merodach,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4754 0.3066 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4092 0.3037 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3641 0.3035 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2744 0.3111 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2098 0.3018 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1849 0.3069 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1208 0.3013 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0981 0.3024 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0423 0.3034 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0121 0.3313 sec/batch
# Nearest to no: stick, seats, form, agents, tense, pattern, mostly, mica,
# Nearest to they: men, economies, engraved, fossil, flatland, types, composing, meters,
# Nearest to eight: notaries, decide, creoles, hacker, choices, motets, aves, mainland,
# Nearest to five: master, country, posters, eds, painful, slays, kurds, dizzy,
# Nearest to time: made, true, thirsty, vroma, hemp, biggest, allowable, derrick,
# Nearest to where: arcades, abaddon, varies, sepia, strolling, commissioned, verde, steve,
# Nearest to three: agreement, chronos, hurts, compared, issue, administrative, weather, prior,
# Nearest to world: norouz, typewriters, taraza, harnack, representing, onassis, yellow, lebanese,
# Nearest to alternative: mcmahon, involvements, organisations, infrared, apr, dispose, lamenting, cleveland,
# Nearest to animals: prepared, ac, landing, aqsa, boomer, control, fundraising, paid,
# Nearest to grand: abbey, unbroken, dench, surname, knotted, pendant, gelderland, conditioned,
# Nearest to channel: your, existing, melancholic, depicted, across, dollar, relapsed, investigation,
# Nearest to something: heavily, rightness, alberti, exchanging, unsafe, sinusoidal, ryan, sputnik,
# Nearest to institute: kami, vigilantes, perceptions, institutes, geopolitical, cybernetic, calories, standby,
# Nearest to quite: challenged, introduces, regardless, attributes, dogsled, producer, orators, inaccuracies,
# Nearest to paris: numerous, tensor, belichick, yao, protestantism, eocene, murdock, heavyweight,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9270 0.3070 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9018 0.3028 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8846 0.3006 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8584 0.3103 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7944 0.3262 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8371 0.3553 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8007 0.3823 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7949 0.3097 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7974 0.3244 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7706 0.3365 sec/batch
# Nearest to no: tense, stick, seats, mica, khoikhoi, pattern, form, predictable,
# Nearest to they: fossil, dare, men, flatland, economies, engraved, scoring, couturat,
# Nearest to eight: notaries, creoles, motets, decide, choices, aves, konstantin, bloomington,
# Nearest to five: master, prussia, posters, assembl, painful, country, kurds, eds,
# Nearest to time: allowable, fi, thirsty, enrico, hemp, comics, true, biggest,
# Nearest to where: arcades, abaddon, strolling, varies, sepia, pouring, verde, commissioned,
# Nearest to three: agreement, administrative, compared, chronos, four, tiananmen, hurts, sc,
# Nearest to world: norouz, typewriters, inaugural, taraza, grass, harnack, onassis, representing,
# Nearest to alternative: infrared, mcmahon, involvements, organisations, outdoor, prove, controlling, slept,
# Nearest to animals: prepared, landing, aqsa, boomer, ac, fundraising, amoeboid, control,
# Nearest to grand: unbroken, abbey, surname, xp, dench, knotted, conditioned, nightclub,
# Nearest to channel: your, existing, dollar, melancholic, investigation, across, relapsed, afoul,
# Nearest to something: heavily, ryan, unsafe, exchanging, sputnik, rightness, alberti, sinusoidal,
# Nearest to institute: perceptions, geopolitical, institutes, rules, kami, vigilantes, optic, cybernetic,
# Nearest to quite: challenged, introduces, orators, producer, inaccuracies, doubt, fetuses, andover,
# Nearest to paris: numerous, tensor, protestantism, yao, galleries, generalissimo, belichick, imitation,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7775 0.3756 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7441 0.3564 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7136 0.3606 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7067 0.3588 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7245 0.3694 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6890 0.3681 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6881 0.3314 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7054 0.2989 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7012 0.2975 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6346 0.2984 sec/batch
# Nearest to no: tense, stick, khoikhoi, mica, falsifiable, seats, predictable, knicks,
# Nearest to they: dare, couturat, fossil, men, deserved, antecedents, engraved, flatland,
# Nearest to eight: actress, motets, nine, notaries, bloomington, observances, konstantin, creoles,
# Nearest to five: assembl, zero, prussia, kurds, master, reggae, dizzy, prover,
# Nearest to time: thirsty, allowable, gym, fi, enrico, derrick, biggest, comics,
# Nearest to where: arcades, abaddon, strolling, sepia, varies, verde, pouring, reincarnation,
# Nearest to three: four, seven, six, agreement, tiananmen, sc, rhone, poked,
# Nearest to world: typewriters, onassis, taraza, inaugural, litres, norouz, grass, harnack,
# Nearest to alternative: infrared, mcmahon, involvements, slept, organisations, outdoor, harshly, lamenting,
# Nearest to animals: aqsa, prepared, landing, boomer, amoeboid, ac, fundraising, abilities,
# Nearest to grand: abbey, unbroken, won, xp, surname, nightclub, knotted, gelderland,
# Nearest to channel: your, melancholic, dollar, existing, trotsky, relapsed, across, investigation,
# Nearest to something: ryan, unsafe, sputnik, exchanging, rightness, mclain, heavily, sinusoidal,
# Nearest to institute: geopolitical, kami, vigilantes, institutes, perceptions, optic, rules, standby,
# Nearest to quite: challenged, introduces, orators, fetuses, andover, watertight, iole, inaccuracies,
# Nearest to paris: numerous, protestantism, yao, octaves, taper, midrash, tensor, boise,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6745 0.3060 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6729 0.2923 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6035 0.2992 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6365 0.2969 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6295 0.2963 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6306 0.2958 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5773 0.2167 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5374 0.2941 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5091 0.2934 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5118 0.2931 sec/batch
# Nearest to no: tense, stick, falsifiable, mica, khoikhoi, seats, ntt, predictable,
# Nearest to they: collisions, men, individualists, dare, couturat, headwaters, antecedents, types,
# Nearest to eight: actress, nine, observances, seven, notaries, martin, politician, actor,
# Nearest to five: zero, assembl, one, kurds, songwriter, prussia, reggae, eds,
# Nearest to time: thirsty, gym, allowable, biggest, enrico, comics, cynical, derrick,
# Nearest to where: arcades, abaddon, strolling, sepia, redmond, veteris, distinctions, verde,
# Nearest to three: four, seven, six, rhone, moncton, one, baron, tiananmen,
# Nearest to world: typewriters, inaugural, onassis, litres, taraza, screenplays, norouz, vietnamese,
# Nearest to alternative: infrared, involvements, mcmahon, lamenting, formalisms, angst, slept, gunshot,
# Nearest to animals: prepared, aqsa, boomer, amoeboid, abilities, landing, fundraising, ac,
# Nearest to grand: abbey, won, unbroken, xp, nightclub, surname, pendant, louis,
# Nearest to channel: your, melancholic, existing, across, cyclical, dollar, trotsky, relapsed,
# Nearest to something: unsafe, sputnik, ryan, mclain, heavily, exchanging, rightness, pastiches,
# Nearest to institute: geopolitical, institutes, vigilantes, kami, standby, optic, perceptions, groundbreaking,
# Nearest to quite: challenged, fetuses, orators, iole, introduces, watertight, andover, nothing,
# Nearest to paris: numerous, yao, taper, midrash, protestantism, sepulchre, et, octaves,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5102 0.3008 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4979 0.2979 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4500 0.2937 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5260 0.2912 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4942 0.2917 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4581 0.2914 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4515 0.2907 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4037 0.2907 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4339 0.2936 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4401 0.3345 sec/batch
# Nearest to no: stick, tense, falsifiable, khoikhoi, mica, debbie, ntt, predictable,
# Nearest to they: men, collisions, nerves, couturat, dare, apek, antecedents, engraved,
# Nearest to eight: motets, martin, actress, notaries, bloomington, konstantin, creoles, observances,
# Nearest to five: zero, kurds, assembl, prover, deaths, federalist, reggae, one,
# Nearest to time: thirsty, gym, enrico, allowable, biggest, signifies, fi, derrick,
# Nearest to where: abaddon, sepia, strolling, arcades, varies, pouring, veteris, distinctions,
# Nearest to three: four, six, seven, chronos, moncton, indisputably, jordanians, zero,
# Nearest to world: typewriters, inaugural, onassis, litres, taraza, rigel, parables, takahashi,
# Nearest to alternative: infrared, involvements, lamenting, mcmahon, angst, organisations, slept, sparc,
# Nearest to animals: prepared, aqsa, abilities, boomer, amoeboid, barley, nicotine, control,
# Nearest to grand: won, abbey, unbroken, xp, surname, gelderland, moqed, clarence,
# Nearest to channel: your, melancholic, links, trotsky, across, existing, relapsed, afoul,
# Nearest to something: unsafe, sputnik, heavily, mclain, exchanging, pastiches, rightness, ryan,
# Nearest to institute: geopolitical, institutes, standby, kami, vigilantes, optic, magni, rainer,
# Nearest to quite: challenged, nothing, watertight, fetuses, iole, attributes, introduces, orators,
# Nearest to paris: numerous, yao, et, sepulchre, buster, belichick, taper, midrash,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4137 0.3353 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4353 0.3246 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4520 0.3039 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4016 0.2982 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4461 0.3854 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4397 0.3870 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3704 0.3387 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.4011 0.2860 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4354 0.2878 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3611 0.2848 sec/batch
# Nearest to no: falsifiable, stick, tense, debbie, khoikhoi, ntt, seats, ilium,
# Nearest to they: men, couturat, collisions, nerves, dare, individualists, apek, celibacy,
# Nearest to eight: actress, martin, nine, seven, motets, zero, notaries, bloomington,
# Nearest to five: zero, one, kurds, six, prover, schule, eds, belgian,
# Nearest to time: gym, thirsty, fi, biggest, allowable, enrico, intrigues, signifies,
# Nearest to where: abaddon, sepia, strolling, pouring, arcades, clearer, seth, eur,
# Nearest to three: four, seven, six, zero, moncton, bazin, two, chronos,
# Nearest to world: typewriters, inaugural, onassis, litres, grass, taraza, rigel, takahashi,
# Nearest to alternative: infrared, involvements, angst, lamenting, sparc, mcmahon, organisations, ballplayer,
# Nearest to animals: prepared, abilities, aqsa, amoeboid, fruit, boomer, barley, nicotine,
# Nearest to grand: won, abbey, nightclub, xp, gelderland, moqed, unbroken, surname,
# Nearest to channel: your, melancholic, links, across, existing, trotsky, gto, relapsed,
# Nearest to something: unsafe, sputnik, exchanging, mclain, pastiches, heavily, rightness, animators,
# Nearest to institute: geopolitical, institutes, magni, optic, retro, vigilantes, standby, kami,
# Nearest to quite: challenged, fetuses, watertight, there, iole, easier, attributes, nothing,
# Nearest to paris: numerous, et, belichick, yao, galleries, sepulchre, buster, boise,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3824 0.2894 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3914 0.3359 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3839 0.2767 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3556 0.2646 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3703 0.2669 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3706 0.2655 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3915 0.2709 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3863 0.3021 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3317 0.2931 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2837 0.2762 sec/batch
# Nearest to no: falsifiable, tense, stick, khoikhoi, debbie, individualistic, ntt, tartar,
# Nearest to they: couturat, men, collisions, travail, cleansing, assembles, dare, would,
# Nearest to eight: zero, seven, nine, notaries, martin, six, one, cellphone,
# Nearest to five: zero, one, six, kurds, two, assembl, schule, eds,
# Nearest to time: gym, thirsty, pedagogic, biggest, intrigues, enrico, allowable, knees,
# Nearest to where: abaddon, amn, clearer, strolling, pouring, sepia, eur, seth,
# Nearest to three: four, six, seven, zero, two, jordanians, moncton, bazin,
# Nearest to world: inaugural, typewriters, onassis, litres, parables, takahashi, etat, taraza,
# Nearest to alternative: infrared, involvements, angst, mcmahon, lamenting, organisations, ballplayer, sparc,
# Nearest to animals: prepared, amoeboid, abilities, fruit, boomer, blanket, barley, transmembrane,
# Nearest to grand: won, abbey, gelderland, surname, xp, knotted, unbroken, nightclub,
# Nearest to channel: your, links, gto, trotsky, melancholic, across, network, vicars,
# Nearest to something: sputnik, unsafe, mclain, heavily, exchanging, pastiches, animators, rightness,
# Nearest to institute: geopolitical, institutes, retro, standby, magni, optic, groundbreaking, kami,
# Nearest to quite: challenged, watertight, attributes, iole, fetuses, introduces, easier, there,
# Nearest to paris: numerous, et, yao, belichick, galleries, sepulchre, buster, triumph,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3234 0.2797 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2933 0.2746 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3923 0.2702 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3621 0.2680 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3764 0.2678 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3246 0.2711 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3039 0.2648 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3302 0.2679 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2266 0.2692 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3237 0.2679 sec/batch
# Nearest to no: falsifiable, tense, stick, khoikhoi, debbie, tartar, ntt, mica,
# Nearest to they: couturat, men, travail, collisions, cleansing, antecedents, adept, assembles,
# Nearest to eight: seven, one, zero, nine, six, actress, martin, konstantin,
# Nearest to five: zero, one, six, two, seven, kurds, belgian, assembl,
# Nearest to time: gym, thirsty, pedagogic, knees, imbibed, incubate, fi, signifies,
# Nearest to where: abaddon, amn, strolling, kart, pouring, sepia, clearer, eur,
# Nearest to three: four, seven, six, two, zero, one, bazin, jordanians,
# Nearest to world: typewriters, inaugural, lebanese, takahashi, kitts, litres, onassis, etat,
# Nearest to alternative: infrared, involvements, angst, ballplayer, mcmahon, organisations, slept, lamenting,
# Nearest to animals: prepared, amoeboid, fruit, abilities, barley, blanket, boomer, attractors,
# Nearest to grand: abbey, surname, won, gelderland, unbroken, nightclub, moqed, xp,
# Nearest to channel: your, links, network, across, gto, tcp, melancholic, vicars,
# Nearest to something: pastiches, mclain, heavily, unsafe, sputnik, presumed, animators, rightness,
# Nearest to institute: institutes, standby, geopolitical, retro, magni, groundbreaking, cru, optic,
# Nearest to quite: watertight, iole, attributes, challenged, easier, lexeme, phishing, fetuses,
# Nearest to paris: numerous, et, yao, galleries, buster, belichick, sepulchre, triumph,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2983 0.2757 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2964 0.2671 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3464 0.1302 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2338 0.2705 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2230 0.2681 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2237 0.2650 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2067 0.2651 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1923 0.2645 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2187 0.2662 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2012 0.2651 sec/batch
# Nearest to no: falsifiable, stick, tense, debbie, individualistic, leaflets, khoikhoi, tartar,
# Nearest to they: couturat, men, travail, cleansing, collisions, adept, assembles, would,
# Nearest to eight: seven, zero, six, one, nine, cellphone, actress, eprdf,
# Nearest to five: zero, six, one, two, kurds, seven, assembl, deaths,
# Nearest to time: gym, thirsty, wellesley, ballast, knees, slots, signifies, pedagogic,
# Nearest to where: kart, abaddon, amn, pouring, strolling, cochrane, sepia, rightful,
# Nearest to three: four, seven, six, zero, two, montagu, one, jordanians,
# Nearest to world: inaugural, typewriters, rigel, presuming, bahrain, litres, onassis, lebanese,
# Nearest to alternative: infrared, involvements, angst, organisations, ballplayer, slept, sparc, lamenting,
# Nearest to animals: prepared, amoeboid, fruit, abilities, blanket, barley, detoxify, attractors,
# Nearest to grand: won, gelderland, surname, unbroken, abbey, dench, nightclub, xp,
# Nearest to channel: your, across, gto, network, links, dab, vicars, melancholic,
# Nearest to something: pastiches, mclain, sputnik, heavily, animators, rightness, unsafe, presumed,
# Nearest to institute: institutes, standby, geopolitical, magni, retro, advanced, research, cru,
# Nearest to quite: watertight, iole, attributes, lexeme, phishing, easier, inaccuracies, preprocessor,
# Nearest to paris: numerous, et, yao, belichick, galleries, murdock, tamers, buster,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2584 0.2713 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2306 0.2623 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2219 0.2658 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1394 0.2693 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1668 0.2652 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1680 0.2635 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1703 0.2613 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2021 0.2679 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1987 0.2670 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1804 0.2640 sec/batch
# Nearest to no: stick, falsifiable, tense, individualistic, leaflets, debbie, tartar, khoikhoi,
# Nearest to they: couturat, travail, men, collisions, cleansing, lalor, adept, canonical,
# Nearest to eight: zero, seven, six, one, nine, cellphone, eprdf, yvonne,
# Nearest to five: zero, six, two, one, kurds, deaths, seven, uqbar,
# Nearest to time: gym, knees, slots, thirsty, solved, wellesley, pedagogic, signifies,
# Nearest to where: pouring, abaddon, kart, amn, strolling, sepia, casinos, cochrane,
# Nearest to three: four, six, seven, zero, two, one, jordanians, five,
# Nearest to world: typewriters, inaugural, rigel, leaflet, presuming, sda, litres, thrashing,
# Nearest to alternative: infrared, involvements, organisations, angst, ballplayer, slept, mainstream, sparc,
# Nearest to animals: prepared, fruit, blanket, amoeboid, abilities, mammals, detoxify, barley,
# Nearest to grand: unbroken, surname, gelderland, abbey, nightclub, dench, xp, won,
# Nearest to channel: your, network, across, dab, gto, vicars, hexer, links,
# Nearest to something: heavily, pastiches, mclain, rightness, presumed, animators, sputnik, unsafe,
# Nearest to institute: institutes, technology, colleges, research, bachelor, magni, standby, enrolled,
# Nearest to quite: watertight, easier, trixie, attributes, iole, lexeme, nebulous, nynorsk,
# Nearest to paris: et, numerous, galleries, yao, belichick, tamers, histoire, buster,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1665 0.2675 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2131 0.2622 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1903 0.2682 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1525 0.2641 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1689 0.2633 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1675 0.2715 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2043 0.2735 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1283 0.2713 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1370 0.2655 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1653 0.2704 sec/batch
# Nearest to no: falsifiable, stick, debbie, tense, individualistic, khoikhoi, andante, apologies,
# Nearest to they: couturat, men, travail, sanctuary, canonical, lalor, collisions, would,
# Nearest to eight: zero, seven, six, one, nine, eprdf, cellphone, konstantin,
# Nearest to five: zero, six, one, two, seven, three, four, deaths,
# Nearest to time: gym, slots, pedagogic, solved, predictions, knees, fi, incubate,
# Nearest to where: kart, abaddon, pouring, amn, traveling, sepia, casinos, seth,
# Nearest to three: four, zero, two, seven, six, five, one, jordanians,
# Nearest to world: typewriters, inaugural, leaflet, rigel, thrashing, install, presuming, arsenal,
# Nearest to alternative: infrared, organisations, angst, involvements, ballplayer, mainstream, sparc, mcmahon,
# Nearest to animals: prepared, fruit, blanket, mammals, amoeboid, abilities, detoxify, nutrients,
# Nearest to grand: xp, unbroken, gelderland, knotted, nightclub, surname, abbey, dench,
# Nearest to channel: your, network, across, dab, gto, hexer, vicars, links,
# Nearest to something: rightness, unsafe, pastiches, presumed, heavily, mclain, sputnik, exchanging,
# Nearest to institute: institutes, colleges, research, technology, bachelor, magni, standby, enrolled,
# Nearest to quite: attributes, introduces, easier, iole, watertight, pinching, trixie, preprocessor,
# Nearest to paris: et, numerous, belichick, galleries, tamers, yao, triumph, histoire,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2206 0.2713 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1893 0.2700 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1871 0.2645 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1973 0.2672 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1366 0.2671 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1597 0.2921 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1638 0.2860 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1278 0.2817 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1991 0.2743 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2124 0.2901 sec/batch
# Nearest to no: falsifiable, stick, individualistic, debbie, khoikhoi, tense, tartar, andante,
# Nearest to they: couturat, men, travail, canonical, sanctuary, strikeouts, hotspur, adept,
# Nearest to eight: seven, zero, six, one, nine, two, martin, konstantin,
# Nearest to five: zero, one, two, six, three, seven, four, deaths,
# Nearest to time: gym, pedagogic, crown, fi, knees, wellesley, cynical, slots,
# Nearest to where: amn, kart, abaddon, pouring, seth, cochrane, rightful, sepia,
# Nearest to three: four, zero, two, six, seven, one, five, nine,
# Nearest to world: typewriters, inaugural, leaflet, takahashi, countryside, thrashing, sda, arsenal,
# Nearest to alternative: organisations, involvements, infrared, angst, emoticons, mainstream, ballplayer, mcmahon,
# Nearest to animals: blanket, prepared, abilities, mammals, fruit, amoeboid, nutrients, shaped,
# Nearest to grand: surname, gelderland, unbroken, xp, moqed, nightclub, louis, won,
# Nearest to channel: network, your, dab, across, electrified, tcp, gto, vicars,
# Nearest to something: pastiches, rightness, mclain, presumed, unsafe, heavily, perkins, exchanging,
# Nearest to institute: institutes, research, colleges, technology, bachelor, standby, enrolled, cru,
# Nearest to quite: attributes, iole, easier, watertight, nynorsk, introduces, trixie, panegyric,
# Nearest to paris: et, numerous, histoire, tamers, galleries, yao, reciprocity, belichick,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2278 0.3246 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1356 0.3879 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1369 0.3405 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1571 0.2800 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0426 0.3015 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1546 0.2747 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1429 0.2688 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1323 0.2704 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1883 0.0590 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1031 0.2920 sec/batch
# Nearest to no: falsifiable, stick, andante, tense, individualistic, tartar, khoikhoi, apologies,
# Nearest to they: couturat, men, travail, strikeouts, canonical, assembles, sanctuary, adept,
# Nearest to eight: seven, zero, six, one, two, nine, cellphone, eprdf,
# Nearest to five: zero, two, one, six, three, seven, four, deaths,
# Nearest to time: gym, pedagogic, slots, predictions, fi, crown, knees, calculate,
# Nearest to where: amn, kart, pouring, abaddon, parallelogram, cochrane, traveling, sepia,
# Nearest to three: four, zero, two, seven, six, five, one, nine,
# Nearest to world: typewriters, leaflet, inaugural, thrashing, sda, fascism, rigel, arsenal,
# Nearest to alternative: infrared, organisations, involvements, angst, emoticons, mainstream, mcmahon, ballplayer,
# Nearest to animals: blanket, abilities, prepared, mammals, amoeboid, fruit, aromas, detoxify,
# Nearest to grand: unbroken, surname, gelderland, xp, abbey, moqed, theocracy, louis,
# Nearest to channel: your, network, across, dab, electrified, relapsed, hexer, gto,
# Nearest to something: pastiches, rightness, mclain, presumed, subjective, heavily, unsafe, rectified,
# Nearest to institute: institutes, research, bachelor, colleges, technology, enrolled, engineering, cru,
# Nearest to quite: attributes, iole, panegyric, vehicle, easier, watertight, nebulous, preprocessor,
# Nearest to paris: et, numerous, tamers, galleries, histoire, les, reciprocity, nationale,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0650 0.3337 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0868 0.3237 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0979 0.3026 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0639 0.3000 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0724 0.3000 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0492 0.2936 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0922 0.3053 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0930 0.3094 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1160 0.2985 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0298 0.3021 sec/batch
# Nearest to no: falsifiable, andante, stick, khoikhoi, individualistic, tense, debbie, tartar,
# Nearest to they: couturat, men, travail, strikeouts, individualists, assembles, adept, lalor,
# Nearest to eight: zero, seven, six, one, nine, century, eprdf, two,
# Nearest to five: zero, one, two, six, three, four, seven, deaths,
# Nearest to time: gym, slots, pedagogic, crown, calculate, knees, fi, ballast,
# Nearest to where: amn, kart, pouring, casinos, parallelogram, burbank, cochrane, traveling,
# Nearest to three: four, two, zero, six, seven, five, one, nine,
# Nearest to world: typewriters, arsenal, inaugural, sda, leaflet, thrashing, notably, udeac,
# Nearest to alternative: organisations, infrared, involvements, angst, mainstream, emoticons, switcher, ballplayer,
# Nearest to animals: blanket, abilities, prepared, mammals, amoeboid, fruit, aromas, detoxify,
# Nearest to grand: unbroken, surname, xp, gelderland, glimpse, knotted, speed, moqed,
# Nearest to channel: your, network, dab, across, electrified, relapsed, hexer, gto,
# Nearest to something: pastiches, rightness, mclain, presumed, heavily, subjective, unsafe, animators,
# Nearest to institute: institutes, research, bachelor, colleges, technology, enrolled, engineering, standby,
# Nearest to quite: attributes, trixie, watertight, nebulous, iole, nynorsk, vehicle, panegyric,
# Nearest to paris: et, les, nationale, numerous, tamers, histoire, galleries, reciprocity,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0346 0.3066 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0503 0.2972 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0412 0.3012 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0300 0.2915 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0890 0.3128 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0433 0.2847 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0666 0.2863 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1173 0.3285 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0233 0.3259 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0787 0.3133 sec/batch
# Nearest to no: falsifiable, andante, stick, individualistic, tense, khoikhoi, tartar, musicologists,
# Nearest to they: couturat, travail, men, strikeouts, individualists, lalor, canonical, casein,
# Nearest to eight: six, zero, one, seven, nine, two, four, gwh,
# Nearest to five: zero, one, two, six, three, four, seven, deaths,
# Nearest to time: predictions, pedagogic, slots, gym, solved, fi, calculate, crown,
# Nearest to where: traveling, kart, parallelogram, pouring, amn, cochrane, sepia, lagrange,
# Nearest to three: four, two, zero, six, seven, five, one, nine,
# Nearest to world: typewriters, leaflet, platonic, notably, thrashing, inaugural, arsenal, install,
# Nearest to alternative: organisations, infrared, mainstream, angst, involvements, emoticons, mcmahon, ballplayer,
# Nearest to animals: blanket, mammals, abilities, prepared, aromas, amoeboid, reptiles, zebra,
# Nearest to grand: unbroken, surname, xp, gelderland, glimpse, knotted, speed, tortola,
# Nearest to channel: your, network, across, dab, relapsed, electrified, hexer, centimetre,
# Nearest to something: rightness, presumed, pastiches, subjective, rectified, exchanging, tootsie, unsafe,
# Nearest to institute: institutes, technology, research, colleges, bachelor, engineering, enrolled, toronto,
# Nearest to quite: attributes, vehicle, trixie, nynorsk, pinching, iole, truck, preprocessor,
# Nearest to paris: et, les, nationale, histoire, numerous, tamers, galleries, reciprocity,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0692 0.3235 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0779 0.3540 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0956 0.3111 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0623 0.3078 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0605 0.3396 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0512 0.2955 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0746 0.3163 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0672 0.3075 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0716 0.3354 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0860 0.3281 sec/batch
# Nearest to no: falsifiable, andante, individualistic, debbie, better, tense, musicologists, khoikhoi,
# Nearest to they: travail, couturat, strikeouts, lalor, canonical, men, individualists, assembles,
# Nearest to eight: seven, zero, one, six, nine, two, four, century,
# Nearest to five: zero, one, two, six, three, four, seven, deaths,
# Nearest to time: predictions, pedagogic, slots, calculate, fi, gym, crown, electromagnetic,
# Nearest to where: kart, amn, traveling, parallelogram, pouring, cochrane, casinos, abaddon,
# Nearest to three: four, two, zero, six, seven, five, one, nine,
# Nearest to world: typewriters, leaflet, inaugural, thrashing, platonic, arsenal, presuming, ewa,
# Nearest to alternative: organisations, infrared, angst, mainstream, involvements, ballplayer, mcmahon, amici,
# Nearest to animals: mammals, blanket, abilities, reptiles, amoeboid, aromas, prepared, animal,
# Nearest to grand: xp, unbroken, surname, gelderland, glimpse, knotted, speed, ogre,
# Nearest to channel: your, network, dab, across, relapsed, electrified, television, hexer,
# Nearest to something: pastiches, rightness, presumed, tootsie, mclain, rectified, unsafe, insistent,
# Nearest to institute: institutes, technology, research, colleges, bachelor, engineering, enrolled, toronto,
# Nearest to quite: attributes, nynorsk, trixie, panegyric, vehicle, iole, outputting, pinching,
# Nearest to paris: et, histoire, numerous, les, nationale, tamers, reciprocity, galleries,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0562 0.3057 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0098 0.3051 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0601 0.2980 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0664 0.3078 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0864 0.3219 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1154 0.3088 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1333 0.3138 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0484 0.3056 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0401 0.3217 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0671 0.3309 sec/batch
# Nearest to no: falsifiable, andante, individualistic, khoikhoi, musicologists, better, tense, debbie,
# Nearest to they: couturat, strikeouts, travail, wooded, lalor, assembles, pig, runnymede,
# Nearest to eight: seven, six, zero, one, nine, two, four, gasparo,
# Nearest to five: zero, two, one, six, three, four, seven, deaths,
# Nearest to time: predictions, slots, calculate, pedagogic, fi, gym, crown, yucca,
# Nearest to where: parallelogram, amn, kart, traveling, lagrange, cochrane, seth, pouring,
# Nearest to three: four, two, zero, six, seven, five, one, nine,
# Nearest to world: typewriters, platonic, countryside, sda, leaflet, inaugural, statistics, ewa,
# Nearest to alternative: organisations, infrared, involvements, ballplayer, emoticons, mainstream, mcmahon, switcher,
# Nearest to animals: blanket, abilities, mammals, reptiles, walruses, zebra, amoeboid, aromas,
# Nearest to grand: surname, unbroken, xp, glimpse, gelderland, louis, ogre, knotted,
# Nearest to channel: your, network, across, electrified, dab, relapsed, subway, centimetre,
# Nearest to something: pastiches, rightness, presumed, rectified, subjective, perkins, tootsie, exchanging,
# Nearest to institute: institutes, technology, research, bachelor, colleges, enrolled, engineering, postdoctoral,
# Nearest to quite: attributes, panegyric, nynorsk, trixie, pinching, outputting, easier, vehicle,
# Nearest to paris: et, histoire, numerous, les, nationale, tamers, galleries, des,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9792 0.3749 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0093 0.3680 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0256 0.3507 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0518 0.3339 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0727 0.3347 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0516 0.2751 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0313 0.3193 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9878 0.3797 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0137 0.3703 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9870 0.2969 sec/batch
# Nearest to no: andante, falsifiable, khoikhoi, individualistic, better, apologies, musicologists, stick,
# Nearest to they: couturat, travail, strikeouts, assembles, men, pig, wooded, canonical,
# Nearest to eight: seven, one, six, zero, nine, two, four, five,
# Nearest to five: zero, one, two, six, three, four, seven, deaths,
# Nearest to time: predictions, calculate, slots, gym, pedagogic, fi, deceleration, electromagnetic,
# Nearest to where: parallelogram, kart, traveling, pouring, amn, cochrane, overlooking, sepia,
# Nearest to three: four, two, zero, six, seven, five, one, nine,
# Nearest to world: typewriters, platonic, leaflet, emblematic, arsenal, ewa, countryside, statistics,
# Nearest to alternative: organisations, infrared, mainstream, emoticons, antidepressant, involvements, angst, amici,
# Nearest to animals: blanket, abilities, mammals, zebra, reptiles, walruses, animal, amoeboid,
# Nearest to grand: surname, unbroken, xp, glimpse, theocracy, ogre, gelderland, speed,
# Nearest to channel: your, across, network, dab, relapsed, electrified, hexer, centimetre,
# Nearest to something: pastiches, rightness, presumed, rectified, perkins, subjective, insistent, tootsie,
# Nearest to institute: institutes, technology, research, bachelor, colleges, engineering, enrolled, postdoctoral,
# Nearest to quite: attributes, panegyric, nynorsk, trixie, charon, there, iole, bloodlines,
# Nearest to paris: et, les, histoire, nationale, des, numerous, tamers, galleries,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0036 0.3678 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9169 0.3601 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0666 0.2909 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0276 0.3095 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0237 0.2813 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0081 0.2968 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9262 0.2763 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9745 0.2770 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9218 0.2741 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9817 0.2996 sec/batch
# Nearest to no: andante, falsifiable, better, khoikhoi, individualistic, tartar, gs, musicologists,
# Nearest to they: strikeouts, couturat, men, pig, wooded, assembles, travail, lalor,
# Nearest to eight: zero, seven, one, six, two, nine, four, five,
# Nearest to five: zero, one, two, six, three, four, seven, deaths,
# Nearest to time: predictions, calculate, gym, slots, fi, pedagogic, ntsc, deceleration,
# Nearest to where: parallelogram, traveling, pouring, kart, necessitating, amn, casinos, cochrane,
# Nearest to three: four, two, zero, six, five, seven, one, nine,
# Nearest to world: typewriters, inaugural, arsenal, sda, statistics, udeac, ewa, platonic,
# Nearest to alternative: organisations, mainstream, infrared, ballplayer, involvements, emoticons, angst, antidepressant,
# Nearest to animals: blanket, abilities, zebra, mammals, reptiles, walruses, animal, amoeboid,
# Nearest to grand: unbroken, surname, xp, tortola, speed, glimpse, gelderland, ogre,
# Nearest to channel: your, across, dab, network, television, relapsed, hexer, itv,
# Nearest to something: pastiches, rightness, presumed, perkins, subjective, rectified, tootsie, mclain,
# Nearest to institute: institutes, technology, research, bachelor, colleges, engineering, postdoctoral, enrolled,
# Nearest to quite: trixie, nynorsk, attributes, foamy, pinching, panegyric, there, charon,
# Nearest to paris: et, les, nationale, histoire, des, numerous, tamers, reciprocity,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9835 0.2976 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9713 0.2733 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0111 0.2767 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0251 0.2788 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9976 0.2795 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9643 0.2782 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9931 0.2745 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9943 0.2735 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0173 0.2785 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9782 0.2732 sec/batch
# Nearest to no: andante, falsifiable, better, apologies, individualistic, predictable, gs, spark,
# Nearest to they: strikeouts, couturat, runnymede, pig, travail, lalor, participate, wooded,
# Nearest to eight: one, seven, six, zero, nine, two, four, five,
# Nearest to five: one, zero, two, six, three, four, seven, eight,
# Nearest to time: predictions, calculate, fi, slots, ntsc, gym, deceleration, yucca,
# Nearest to where: parallelogram, traveling, kart, pouring, cochrane, amn, phi, burbank,
# Nearest to three: four, two, zero, six, seven, five, one, nine,
# Nearest to world: typewriters, inaugural, pathologists, platonic, arsenal, leaflet, udeac, match,
# Nearest to alternative: organisations, infrared, mainstream, emoticons, ballplayer, mcmahon, amici, involvements,
# Nearest to animals: blanket, abilities, zebra, mammals, walruses, reptiles, bonobo, animal,
# Nearest to grand: unbroken, xp, surname, speed, knotted, glimpse, ogre, alliaceae,
# Nearest to channel: your, across, dab, relapsed, network, television, tv, hexer,
# Nearest to something: rightness, pastiches, presumed, perkins, subjective, exchanging, rectified, dreaming,
# Nearest to institute: institutes, technology, research, colleges, bachelor, engineering, postdoctoral, advanced,
# Nearest to quite: nynorsk, trixie, panegyric, charon, attributes, foamy, truck, pinching,
# Nearest to paris: et, les, nationale, histoire, des, salon, reciprocity, phane,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0082 0.2798 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9883 0.2763 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9762 0.2752 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9895 0.2834 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0443 0.2795 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0046 0.2725 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9550 0.2739 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9567 0.2763 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9775 0.2803 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0226 0.3122 sec/batch
# Nearest to no: andante, falsifiable, better, individualistic, apologies, khoikhoi, estates, predictable,
# Nearest to they: couturat, strikeouts, travail, pig, are, bedouins, wooded, men,
# Nearest to eight: one, seven, six, zero, nine, two, four, five,
# Nearest to five: zero, one, two, six, three, four, seven, eight,
# Nearest to time: predictions, pedagogic, calculate, fi, slots, ntsc, pomegranate, confessio,
# Nearest to where: parallelogram, traveling, amn, phi, kart, nonmetals, overlooking, lagrange,
# Nearest to three: four, two, zero, six, seven, five, one, nine,
# Nearest to world: pathologists, typewriters, inaugural, udeac, arsenal, leaflet, countryside, platonic,
# Nearest to alternative: organisations, emoticons, mainstream, infrared, ballplayer, amici, mcmahon, switcher,
# Nearest to animals: blanket, abilities, walruses, zebra, animal, bonobo, mammals, amoeboid,
# Nearest to grand: surname, speed, unbroken, glimpse, ogre, xp, knotted, vitriolic,
# Nearest to channel: your, across, dab, network, relapsed, electrified, centimetre, television,
# Nearest to something: pastiches, rightness, perkins, subjective, presumed, exchanging, associate, thine,
# Nearest to institute: institutes, technology, research, bachelor, engineering, colleges, postdoctoral, enrolled,
# Nearest to quite: panegyric, nynorsk, trixie, attributes, foamy, easier, pinching, charon,
# Nearest to paris: et, les, histoire, nationale, des, phane, reciprocity, salon,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9743 0.2819 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0625 0.2896 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0542 0.2734 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0351 0.2727 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9427 0.2861 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9459 0.2706 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9812 0.2734 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9484 0.2759 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9695 0.2745 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9600 0.2734 sec/batch
# ...
# Nearest to they: were, to, them, their, are, that, these, just,
# Nearest to eight: one, seven, zero, six, four, nine, five, two,
# Nearest to five: two, zero, one, three, six, four, eight, seven,
# Nearest to time: ntsc, to, fi, predictions, impregnated, up, correctly, previous,
# Nearest to where: parallelogram, times, then, in, traveling, cot, and, overlooking,
# Nearest to three: four, two, zero, five, six, one, seven, nine,
# Nearest to world: udeac, hurled, envision, medals, clip, statistics, pathologists, platonic,
# Nearest to alternative: mainstream, amici, emoticons, organisations, omnidirectional, ballplayer, involvements, marlene,
# Nearest to animals: tirol, walruses, bonobo, zebra, abilities, blanket, animal, amniotes,
# Nearest to grand: emptiness, knights, surname, disaffection, durand, scouting, clines, damian,
# Nearest to channel: tv, channels, your, television, itv, network, dab, relapsed,
# Nearest to something: perkins, willing, simpler, saying, associate, subjective, passers, insistent,
# Nearest to institute: technology, institutes, bachelor, dortmund, research, postdoctoral, engineering, horkheimer,
# Nearest to quite: tri, rubbery, panegyric, wpm, translator, snowmobile, somewhat, xiaoping,
# Nearest to paris: et, nationale, les, salon, mie, reciprocity, phane, jean,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8378 0.2723 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8377 0.2638 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8515 0.2653 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8542 0.2664 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8800 0.2637 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8813 0.2703 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8382 0.2635 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8261 0.2657 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8805 0.2651 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9037 0.2654 sec/batch
# Nearest to no: andante, lennox, info, jargon, phenotype, shortcut, sysop, individualistic,
# Nearest to they: were, to, them, their, that, are, these, harbinger,
# Nearest to eight: one, seven, four, zero, six, two, five, nine,
# Nearest to five: two, one, zero, three, four, six, seven, eight,
# Nearest to time: ntsc, to, predictions, runic, fi, confessio, period, spectroscopic,
# Nearest to where: parallelogram, in, times, then, and, edifices, traveling, overlooking,
# Nearest to three: four, two, zero, five, one, seven, six, nine,
# Nearest to world: udeac, in, ii, international, war, inaugural, tournament, pathologists,
# Nearest to alternative: mainstream, amici, emoticons, organisations, omnidirectional, ballplayer, infrared, dispelling,
# Nearest to animals: bonobo, walruses, tirol, zebra, animal, blanket, abilities, amniotes,
# Nearest to grand: emptiness, surname, knights, disaffection, durand, scouting, clines, xp,
# Nearest to channel: tv, channels, your, itv, network, television, relapsed, dab,
# Nearest to something: perkins, willing, insistent, simpler, saying, subjective, associate, eurosceptics,
# Nearest to institute: technology, institutes, bachelor, postdoctoral, dortmund, horkheimer, research, choreographers,
# Nearest to quite: tri, panegyric, translator, rubbery, wpm, champions, indicated, vorticity,
# Nearest to paris: et, salon, les, mie, phane, nationale, jean, reciprocity,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8935 0.2703 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8143 0.2685 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8265 0.2642 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8260 0.2653 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9012 0.2679 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8233 0.2679 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9795 0.2664 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8842 0.2757 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9010 0.2716 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8235 0.2651 sec/batch
# Nearest to no: andante, lennox, info, jargon, phenotype, shortcut, three, richter,
# Nearest to they: were, to, their, them, are, that, these, merger,
# Nearest to eight: one, seven, four, zero, six, two, five, nine,
# Nearest to five: two, one, zero, three, four, six, seven, eight,
# Nearest to time: he, ntsc, confessio, fi, period, predictions, weeks, receptions,
# Nearest to where: parallelogram, times, then, studied, edifices, soon, and, overlooking,
# Nearest to three: four, two, zero, five, seven, six, one, nine,
# Nearest to world: in, war, udeac, ii, international, medals, statistics, oper,
# Nearest to alternative: mainstream, amici, emoticons, organisations, omnidirectional, ballplayer, misquoted, dispelling,
# Nearest to animals: walruses, bonobo, tirol, zebra, abilities, animal, amniotes, blanket,
# Nearest to grand: emptiness, durand, surname, knights, disaffection, scouting, clines, anatoly,
# Nearest to channel: channels, tv, your, itv, network, relapsed, yamamoto, dab,
# Nearest to something: perkins, willing, saying, subjective, insistent, simpler, passers, eurosceptics,
# Nearest to institute: technology, institutes, bachelor, postdoctoral, dortmund, horkheimer, choreographers, research,
# Nearest to quite: tri, panegyric, rubbery, indicated, wpm, somewhat, vorticity, trixie,
# Nearest to paris: et, salon, les, nationale, phane, mie, jean, emile,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7918 0.2685 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8786 0.2663 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7933 0.2670 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8722 0.2677 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8234 0.2649 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8331 0.2715 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8795 0.1752 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8434 0.2671 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8141 0.2682 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8516 0.2696 sec/batch
# Nearest to no: andante, lennox, phenotype, jargon, info, spouse, yourselves, shortcut,
# Nearest to they: to, were, that, their, them, are, these, admit,
# Nearest to eight: one, seven, four, six, zero, nine, five, two,
# Nearest to five: one, two, zero, three, six, four, seven, eight,
# Nearest to time: to, ntsc, up, weeks, predictions, jamal, he, impregnated,
# Nearest to where: parallelogram, and, soon, in, times, edifices, a, studied,
# Nearest to three: four, two, zero, five, one, seven, six, nine,
# Nearest to world: in, war, ii, s, statistics, international, hurled, medals,
# Nearest to alternative: mainstream, amici, emoticons, organisations, matrimony, omnidirectional, dispelling, misquoted,
# Nearest to animals: animal, walruses, amniotes, tirol, bonobo, zebra, abilities, holistic,
# Nearest to grand: emptiness, durand, knights, clines, disaffection, scouting, surname, anatoly,
# Nearest to channel: channels, your, tv, itv, relapsed, network, yamamoto, television,
# Nearest to something: willing, perkins, simpler, subjective, passers, insistent, eurosceptics, think,
# Nearest to institute: technology, institutes, bachelor, choreographers, horkheimer, postdoctoral, dortmund, research,
# Nearest to quite: panegyric, tri, translator, indicated, supercar, wpm, snowmobile, animators,
# Nearest to paris: et, salon, les, nationale, mans, triumph, phane, mie,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8017 0.2692 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8213 0.2682 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7990 0.2673 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8329 0.2670 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8379 0.2668 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8199 0.2671 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8698 0.2649 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7301 0.2651 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8351 0.2707 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7825 0.2655 sec/batch
# Nearest to no: andante, phenotype, three, lennox, jargon, spouse, is, info,
# Nearest to they: were, to, are, their, them, that, these, merger,
# Nearest to eight: one, four, zero, seven, six, two, five, nine,
# Nearest to five: two, zero, one, three, six, four, seven, eight,
# Nearest to time: to, ntsc, up, period, upto, studying, impregnated, weeks,
# Nearest to where: then, in, parallelogram, and, is, times, a, the,
# Nearest to three: four, two, zero, five, six, seven, one, nine,
# Nearest to world: international, war, in, statistics, ii, s, hurled, udeac,
# Nearest to alternative: mainstream, amici, organisations, emoticons, misquoted, omnidirectional, dispelling, matrimony,
# Nearest to animals: animal, walruses, zebra, abilities, tirol, amniotes, bonobo, blanket,
# Nearest to grand: emptiness, durand, knights, scouting, disaffection, cardiovascular, clines, surname,
# Nearest to channel: channels, tv, your, itv, television, relapsed, network, yamamoto,
# Nearest to something: willing, perkins, passers, simpler, subjective, saying, eurosceptics, insistent,
# Nearest to institute: technology, institutes, bachelor, research, postdoctoral, choreographers, dortmund, horkheimer,
# Nearest to quite: rubbery, tri, snowmobile, wpm, panegyric, translator, animators, somewhat,
# Nearest to paris: et, nationale, salon, triumph, les, mans, mie, reciprocity,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7452 0.2714 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8231 0.2706 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8655 0.2652 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8189 0.2666 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8201 0.2645 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8928 0.2678 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8262 0.2658 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8206 0.2666 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8383 0.2663 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8489 0.2658 sec/batch
# Nearest to no: andante, lennox, spouse, phenotype, three, richter, reis, comparable,
# Nearest to they: were, to, them, are, their, that, these, merger,
# Nearest to eight: one, four, seven, zero, two, six, five, nine,
# Nearest to five: one, two, zero, three, six, four, seven, eight,
# Nearest to time: to, he, predictions, weeks, impregnated, fi, up, ntsc,
# Nearest to where: then, times, and, parallelogram, in, a, is, traveling,
# Nearest to three: four, two, zero, five, one, seven, six, nine,
# Nearest to world: war, ii, international, in, s, hurled, oper, clip,
# Nearest to alternative: mainstream, amici, emoticons, organisations, matrimony, omnidirectional, misquoted, sapkowski,
# Nearest to animals: animal, walruses, tirol, amniotes, zebra, bonobo, blanket, holistic,
# Nearest to grand: emptiness, durand, knights, scouting, disaffection, cardiovascular, clines, vitriolic,
# Nearest to channel: channels, itv, your, yamamoto, relapsed, tv, television, dab,
# Nearest to something: willing, perkins, passers, subjective, simpler, insistent, eurosceptics, associate,
# Nearest to institute: technology, institutes, bachelor, postdoctoral, horkheimer, choreographers, dortmund, programmes,
# Nearest to quite: tri, rubbery, wpm, translator, animators, panegyric, somewhat, snowmobile,
# Nearest to paris: et, salon, nationale, triumph, mans, mie, havre, emile,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8511 0.2706 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8639 0.2668 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8091 0.2731 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8054 0.2680 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8693 0.2685 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8571 0.2682 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8104 0.2646 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8541 0.2711 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8204 0.2680 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8044 0.2637 sec/batch
# Nearest to no: andante, info, jargon, phenotype, lennox, shortcut, three, spouse,
# Nearest to they: were, to, their, them, are, that, these, admit,
# Nearest to eight: one, four, seven, zero, six, two, five, three,
# Nearest to five: one, two, zero, three, four, six, seven, eight,
# Nearest to time: to, up, local, predictions, period, ntsc, valid, runic,
# Nearest to where: parallelogram, times, then, in, and, thais, is, overlooking,
# Nearest to three: four, two, zero, five, one, seven, six, nine,
# Nearest to world: in, war, s, international, ii, medals, udeac, tournament,
# Nearest to alternative: mainstream, amici, emoticons, organisations, matrimony, omnidirectional, misquoted, sapkowski,
# Nearest to animals: walruses, animal, amniotes, bonobo, zebra, thylacine, tirol, blanket,
# Nearest to grand: emptiness, scouting, durand, knights, disaffection, cardiovascular, clines, damian,
# Nearest to channel: channels, relapsed, yamamoto, your, tv, itv, network, brunel,
# Nearest to something: perkins, willing, passers, simpler, eurosceptics, subjective, associate, insistent,
# Nearest to institute: technology, institutes, bachelor, programmes, postdoctoral, dortmund, horkheimer, research,
# Nearest to quite: indicated, tri, wpm, panegyric, vorticity, rubbery, translator, somewhat,
# Nearest to paris: salon, et, nationale, litt, triumph, mans, havre, passy,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8733 0.2714 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8284 0.2692 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9307 0.2698 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8803 0.2657 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8986 0.2676 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7968 0.2694 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7968 0.2613 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8267 0.2653 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7379 0.2685 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8599 0.2687 sec/batch
# Nearest to no: andante, info, lennox, jargon, phenotype, richter, spouse, is,
# Nearest to they: were, them, their, to, are, that, these, admit,
# Nearest to eight: one, seven, four, nine, zero, six, two, five,
# Nearest to five: one, two, zero, three, four, six, seven, eight,
# Nearest to time: to, up, ntsc, fi, weeks, able, work, predictions,
# Nearest to where: parallelogram, then, times, in, a, traveling, and, studied,
# Nearest to three: four, two, zero, five, one, seven, six, nine,
# Nearest to world: in, war, ii, s, international, udeac, oper, hurled,
# Nearest to alternative: mainstream, amici, emoticons, matrimony, organisations, misquoted, sapkowski, omnidirectional,
# Nearest to animals: animal, walruses, amniotes, bonobo, tirol, zebra, thylacine, placentals,
# Nearest to grand: durand, scouting, emptiness, knights, clines, cardiovascular, surname, disaffection,
# Nearest to channel: relapsed, channels, yamamoto, your, itv, tv, network, raleigh,
# Nearest to something: perkins, willing, passers, simpler, saying, subjective, eurosceptics, think,
# Nearest to institute: technology, institutes, postdoctoral, programmes, bachelor, horkheimer, research, choreographers,
# Nearest to quite: indicated, tri, wpm, somewhat, panegyric, supercar, translator, rubbery,
# Nearest to paris: et, salon, nationale, mans, triumph, louvre, havre, emile,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8412 0.2729 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8280 0.2670 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
